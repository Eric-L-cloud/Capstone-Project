# %% [markdown]
# **List of Noteable Variables in this Workbook**
#
# - combined_df : dataset dataframe after removing duplication
# - drop_df : dataset dataframe after removing duplication + missing value
# - drop_df_removed_shift : dataset dataframe after removing duplication + missing value + shifted rows

# %% [markdown]
# ## Import Data & Data Preprocessing

# %%
import pandas as pd

# %%
import numpy as np
import os

# %%
#pip install pyarrow
#pip install fastparquet

# %% [markdown]
# **1. Remove Duplication**

# %% [markdown]
# Step 1: remove duplicate iteration
# (third line of code) The variable "files" inside pd.read_parquet() of the original file is revised to "file" .

# %%
num_files = 15
files = [f"files/batch_{i}.parquet" for i in range(num_files)]

dfs = [pd.read_parquet(file) for file in files]
combined_df = pd.concat(dfs, ignore_index=True)
combined_df
# Out:
#                         Investors                Primary Contact  \
# 0                       Techstars                    David Cohen
# 1                    Y Combinator                     David Lieb
# 2       Plug and Play Tech Center                   Marc Steiner
# 3                        Gaingels                Paul Grossinger
# 4                          Antler               Magnus Grimeland
# ...                           ...                            ...
# 155339                 ECS Tuning                    Imran Jooma
# 155340                   ECSEL JU                              0
# 155341                     Ecster                              0
# 155342                 ECU Health                Michael Waldrum
# 155343              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# 155343  ECU Worldwide is a provider of logistic servic...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155339
# 155340
# 155341
# 155342
# 155343
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155339                Commercial Products, Transportation
# 155340                           Semiconductors, Software
# 155341                                                  0
# 155342                                                  0
# 155343                                          Logistics
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155339             Add-on, Buyout/LBO, Merger/Acquisition
# 155340                                                  0
# 155341                                 Merger/Acquisition
# 155342                                 Merger/Acquisition
# 155343                                 Merger/Acquisition
#
#         Primary Investor Type  \
# 0       Accelerator/Incubator
# 1       Accelerator/Incubator
# 2       Accelerator/Incubator
# 3             Venture Capital
# 4             Venture Capital
# ...                       ...
# 155339                      0
# 155340                      0
# 155341                      0
# 155342                      0
# 155343                      0
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155339                                                 []
# 155340                                                 []
# 155341                                                 []
# 155342                                                 []
# 155343                                                 []
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155339           [add-on, buyout/lbo, merger/acquisition]
# 155340                                                [0]
# 155341                               [merger/acquisition]
# 155342                               [merger/acquisition]
# 155343                               [merger/acquisition]
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155339              [commercial products, transportation]
# 155340                         [semiconductors, software]
# 155341                                                [0]
# 155342                                                [0]
# 155343                                        [logistics]
#
# [155344 rows x 10 columns]

# %% [markdown]
# Step 2: checking all other possible duplications (rows with exactly same row values --> found to be 590 number of rows).

# %%
# If values in a column conatains unhashable data e.g. list / ndarray, formula will return error --> last three columns
# Thus, only use columns with hashable types --> subset of other columns
# This formula will return a series of boolean values indicating whether each row is a duplicate, True = Duplicate

check_duplicates = combined_df.duplicated(subset=['Investors', 'Primary Contact', 'Description', 'Geography', 'Preferred Industry', 'Preferred Investment Type', 'Primary Investor Type'])
print( check_duplicates )

print( check_duplicates.sum() )           # Count of duplicates --> 590
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 155339    False
# 155340    False
# 155341    False
# 155342    False
# 155343    False
# Length: 155344, dtype: bool
# 590

# %%
duplicates_index_number = check_duplicates[check_duplicates == True]
duplicates_index_number.index
# Out:
# Index([ 11372,  26404,  26415,  26517,  32353,  32422,  32967,  33122,  33561,
#         34570,
#        ...
#        153768, 153769, 153774, 153861, 153899, 154109, 154162, 154866, 154867,
#        154873],
#       dtype='int64', length=590)

# %% [markdown]
# The variable "combined_df" here is updated with all duplicates removed.

# %%
combined_df.drop(index = duplicates_index_number.index, inplace=True)  # Drop duplicates
combined_df
# Out:
#                         Investors                Primary Contact  \
# 0                       Techstars                    David Cohen
# 1                    Y Combinator                     David Lieb
# 2       Plug and Play Tech Center                   Marc Steiner
# 3                        Gaingels                Paul Grossinger
# 4                          Antler               Magnus Grimeland
# ...                           ...                            ...
# 155339                 ECS Tuning                    Imran Jooma
# 155340                   ECSEL JU                              0
# 155341                     Ecster                              0
# 155342                 ECU Health                Michael Waldrum
# 155343              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# 155343  ECU Worldwide is a provider of logistic servic...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155339
# 155340
# 155341
# 155342
# 155343
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155339                Commercial Products, Transportation
# 155340                           Semiconductors, Software
# 155341                                                  0
# 155342                                                  0
# 155343                                          Logistics
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155339             Add-on, Buyout/LBO, Merger/Acquisition
# 155340                                                  0
# 155341                                 Merger/Acquisition
# 155342                                 Merger/Acquisition
# 155343                                 Merger/Acquisition
#
#         Primary Investor Type  \
# 0       Accelerator/Incubator
# 1       Accelerator/Incubator
# 2       Accelerator/Incubator
# 3             Venture Capital
# 4             Venture Capital
# ...                       ...
# 155339                      0
# 155340                      0
# 155341                      0
# 155342                      0
# 155343                      0
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155339                                                 []
# 155340                                                 []
# 155341                                                 []
# 155342                                                 []
# 155343                                                 []
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155339           [add-on, buyout/lbo, merger/acquisition]
# 155340                                                [0]
# 155341                               [merger/acquisition]
# 155342                               [merger/acquisition]
# 155343                               [merger/acquisition]
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155339              [commercial products, transportation]
# 155340                         [semiconductors, software]
# 155341                                                [0]
# 155342                                                [0]
# 155343                                        [logistics]
#
# [154754 rows x 10 columns]

# %% [markdown]
# **2. Handle Missing Vlue**

# %%
# import os
# Define the path to your desktop
#desktop_path = os.path.expanduser("~/Desktop/")

# Define the file path for the CSV file on your desktop
#csv_file_path = os.path.join(desktop_path, 'output.csv')

# Export the DataFrame to a CSV file on your desktop
#combined_df.to_csv(csv_file_path, index=False)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154754 entries, 0 to 155343
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Investors                       154754 non-null  object
#  1   Primary Contact                 154753 non-null  object
#  2   Description                     154754 non-null  object
#  3   Geography                       154754 non-null  object
#  4   Preferred Industry              154740 non-null  object
#  5   Preferred Investment Type       154174 non-null  object
#  6   Primary Investor Type           154091 non-null  object
#  7   geography_tags                  154754 non-null  object
#  8   preferred_investment_type_tags  154754 non-null  object
#  9   preferred_industry_tags         154754 non-null  object
# dtypes: object(10)
# memory usage: 13.0+ MB

# %%
combined_df.drop(columns=['Primary Contact'], inplace=True, errors='ignore')

# %%
print(combined_df)
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# 155343  ECU Worldwide is a provider of logistic servic...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155339
# 155340
# 155341
# 155342
# 155343
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155339                Commercial Products, Transportation
# 155340                           Semiconductors, Software
# 155341                                                  0
# 155342                                                  0
# 155343                                          Logistics
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155339             Add-on, Buyout/LBO, Merger/Acquisition
# 155340                                                  0
# 155341                                 Merger/Acquisition
# 155342                                 Merger/Acquisition
# 155343                                 Merger/Acquisition
#
#         Primary Investor Type  \
# 0       Accelerator/Incubator
# 1       Accelerator/Incubator
# 2       Accelerator/Incubator
# 3             Venture Capital
# 4             Venture Capital
# ...                       ...
# 155339                      0
# 155340                      0
# 155341                      0
# 155342                      0
# 155343                      0
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155339                                                 []
# 155340                                                 []
# 155341                                                 []
# 155342                                                 []
# 155343                                                 []
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155339           [add-on, buyout/lbo, merger/acquisition]
# 155340                                                [0]
# 155341                               [merger/acquisition]
# 155342                               [merger/acquisition]
# 155343                               [merger/acquisition]
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155339              [commercial products, transportation]
# 155340                         [semiconductors, software]
# 155341                                                [0]
# 155342                                                [0]
# 155343                                        [logistics]
#
# [154754 rows x 9 columns]

# %%
combined_df.isnull().sum()
# Out:
# Investors                           0
# Description                         0
# Geography                           0
# Preferred Industry                 14
# Preferred Investment Type         580
# Primary Investor Type             663
# geography_tags                      0
# preferred_investment_type_tags      0
# preferred_industry_tags             0
# dtype: int64

# %%
drop_df = combined_df.dropna()

# %%
drop_df
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# 155343  ECU Worldwide is a provider of logistic servic...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155339
# 155340
# 155341
# 155342
# 155343
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155339                Commercial Products, Transportation
# 155340                           Semiconductors, Software
# 155341                                                  0
# 155342                                                  0
# 155343                                          Logistics
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155339             Add-on, Buyout/LBO, Merger/Acquisition
# 155340                                                  0
# 155341                                 Merger/Acquisition
# 155342                                 Merger/Acquisition
# 155343                                 Merger/Acquisition
#
#         Primary Investor Type  \
# 0       Accelerator/Incubator
# 1       Accelerator/Incubator
# 2       Accelerator/Incubator
# 3             Venture Capital
# 4             Venture Capital
# ...                       ...
# 155339                      0
# 155340                      0
# 155341                      0
# 155342                      0
# 155343                      0
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155339                                                 []
# 155340                                                 []
# 155341                                                 []
# 155342                                                 []
# 155343                                                 []
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155339           [add-on, buyout/lbo, merger/acquisition]
# 155340                                                [0]
# 155341                               [merger/acquisition]
# 155342                               [merger/acquisition]
# 155343                               [merger/acquisition]
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155339              [commercial products, transportation]
# 155340                         [semiconductors, software]
# 155341                                                [0]
# 155342                                                [0]
# 155343                                        [logistics]
#
# [154087 rows x 9 columns]

# %%
drop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154087 entries, 0 to 155343
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Investors                       154087 non-null  object
#  1   Description                     154087 non-null  object
#  2   Geography                       154087 non-null  object
#  3   Preferred Industry              154087 non-null  object
#  4   Preferred Investment Type       154087 non-null  object
#  5   Primary Investor Type           154087 non-null  object
#  6   geography_tags                  154087 non-null  object
#  7   preferred_investment_type_tags  154087 non-null  object
#  8   preferred_industry_tags         154087 non-null  object
# dtypes: object(9)
# memory usage: 11.8+ MB

# %%
drop_df.columns
# Out:
# Index(['Investors', 'Description', 'Geography', 'Preferred Industry',
#        'Preferred Investment Type', 'Primary Investor Type', 'geography_tags',
#        'preferred_investment_type_tags', 'preferred_industry_tags'],
#       dtype='object')

# %%
drop_df.isin(['', '0', '[]', '[0]'])
# Out:
#         Investors  Description  Geography  Preferred Industry  \
# 0           False        False      False               False
# 1           False        False      False               False
# 2           False        False      False               False
# 3           False        False      False               False
# 4           False        False      False               False
# ...           ...          ...        ...                 ...
# 155339      False        False       True               False
# 155340      False         True       True               False
# 155341      False        False       True                True
# 155342      False         True       True                True
# 155343      False        False       True               False
#
#         Preferred Investment Type  Primary Investor Type  geography_tags  \
# 0                           False                  False           False
# 1                           False                  False           False
# 2                           False                  False           False
# 3                           False                  False           False
# 4                           False                  False           False
# ...                           ...                    ...             ...
# 155339                      False                   True            True
# 155340                       True                   True            True
# 155341                      False                   True            True
# 155342                      False                   True            True
# 155343                      False                   True            True
#
#         preferred_investment_type_tags  preferred_industry_tags
# 0                                False                    False
# 1                                False                    False
# 2                                False                    False
# 3                                False                    False
# 4                                False                    False
# ...                                ...                      ...
# 155339                           False                    False
# 155340                           False                    False
# 155341                           False                    False
# 155342                           False                    False
# 155343                           False                    False
#
# [154087 rows x 9 columns]

# %%
drop_df.isin(['', '0', '[]', '[0]']).any(axis=1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 155339     True
# 155340     True
# 155341     True
# 155342     True
# 155343     True
# Length: 154087, dtype: bool

# %%
~drop_df.isin(['', '0', '[]', '[0]']).any(axis=1)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 155339    False
# 155340    False
# 155341    False
# 155342    False
# 155343    False
# Length: 154087, dtype: bool

# %%
drop_df = drop_df[~drop_df.isin(['', '0', '[]', '[0]']).any(axis=1)]

# %%
data1 = {
    'Category': ['A', 'B', 'A', 'C', 'B']
}

df3 = pd.DataFrame(data1)

# Convert the categorical column 'Category' into dummy variables
dummy_df = pd.get_dummies(df3['Category'], prefix='Category')

# Concatenate the dummy variables with the original DataFrame
df3 = pd.concat([df3, dummy_df], axis=1)

df3
# Out:
#   Category  Category_A  Category_B  Category_C
# 0        A        True       False       False
# 1        B       False        True       False
# 2        A        True       False       False
# 3        C       False       False        True
# 4        B       False        True       False

# %%
drop_df
# Out:
#                          Investors  \
# 0                        Techstars
# 1                     Y Combinator
# 2        Plug and Play Tech Center
# 3                         Gaingels
# 4                           Antler
# ...                            ...
# 155260          Ecosphere Ventures
# 155262       Ecostar (Accelerator)
# 155270  Ecosystem Ventures (India)
# 155314             Ecphora Capital
# 155331                 ECS Capital
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155260  Founded in 222, Ecosphere Ventures is a ventur...
# 155262  Founded in 216, Ecostar is an accelerator inve...
# 155270  Founded in 218, Ecosystem Ventures is an angel...
# 155314  Founded in 222, Ecphora Capital is a venture c...
# 155331  Founded in 26, ECS Capital is a private equity...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155260                                      United States
# 155262                                             Europe
# 155270                                               Asia
# 155314                                           Maryland
# 155331                                           Portugal
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155260  Building Products, Commercial Transportation, ...
# 155262  Agriculture, Consumer Products and Services (B...
# 155270  Business Products and Services (B2B), Energy, ...
# 155314     Biotechnology, Healthcare Devices and Supplies
# 155331  Business Products and Services (B2B), Consumer...
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155260                         Early Stage VC, Seed Round
# 155262  Accelerator/Incubator, Debt Refinancing, Early...
# 155270         Early Stage VC, Later Stage VC, Seed Round
# 155314                         Early Stage VC, Seed Round
# 155331  Asset Acquisition, Buyout/LBO, Distressed Acqu...
#
#             Primary Investor Type  \
# 0           Accelerator/Incubator
# 1           Accelerator/Incubator
# 2           Accelerator/Incubator
# 3                 Venture Capital
# 4                 Venture Capital
# ...                           ...
# 155260   <span>0.00 - 1.00</span>
# 155262          <span>0.16</span>
# 155270   <span>0.25 - 1.00</span>
# 155314   <span>0.50 - 4.00</span>
# 155331  <span>5.17 - 51.74</span>
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155260                                    [united states]
# 155262                                           [europe]
# 155270                                             [asia]
# 155314                                         [maryland]
# 155331                                         [portugal]
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155260                       [early stage vc, seed round]
# 155262  [accelerator/incubator, debt refinancing, earl...
# 155270       [early stage vc, later stage vc, seed round]
# 155314                       [early stage vc, seed round]
# 155331  [asset acquisition, buyout/lbo, distressed acq...
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155260  [building products, commercial transportation,...
# 155262  [agriculture, consumer products and services (...
# 155270  [business products and services (b2b), energy,...
# 155314   [biotechnology, healthcare devices and supplies]
# 155331  [business products and services (b2b), consume...
#
# [15453 rows x 9 columns]

# %%
drop_df.info()

# import os
# Define the path to your desktop
desktop_path = os.path.expanduser("~/Desktop/")

# Define the file path for the CSV file on your desktop
csv_file_path = os.path.join(desktop_path, 'output2.csv')

# Export the DataFrame to a CSV file on your desktop
drop_df.to_csv(csv_file_path, index=False)

# %% [markdown]
# **3. Remove shifted data.**

# %% [markdown]
# Check shift by checking "www." in the column "Description"

# %%
df_removed_shifted = drop_df[['Description']][drop_df['Description'].str.contains('www.')]
df_removed_shifted
# Out:
#                                   Description
# 118                                www.hf.com
# 251                              www.nhqv.com
# 338                           www.tdpfund.com
# 551                         www.andlinger.com
# 1672                       www.jandjgroup.com
# ...                                       ...
# 153206                     www.dunross.com.cy
# 153629                      www.dynamicpt.com
# 153758                   www.ea-companies.com
# 154717                  www.vertexventures.sg
# 154836  www.ukinnovationscienceseedfund.co.uk
#
# [234 rows x 1 columns]

# %%
index_list_removed_shifted = df_removed_shifted.index.tolist()
index_list_removed_shifted
# Out:
# [118,
#  251,
#  338,
#  551,
#  1672,
#  1867,
#  1873,
#  1950,
#  1959,
#  1960,
#  2437,
#  5767,
#  6040,
#  6983,
#  8058,
#  8590,
#  9463,
#  9474,
#  9475,
#  9536,
#  10128,
#  11483,
#  11612,
#  11826,
#  12002,
#  12370,
#  13490,
#  14180,
#  14196,
#  14418,
#  14590,
#  14766,
#  15135,
#  15141,
#  15438,
#  15733,
#  17349,
#  17360,
#  17959,
#  18049,
#  18062,
#  18170,
#  18191,
#  18576,
#  18787,
#  19131,
#  19226,
#  19972,
#  20308,
#  21556,
#  22484,
#  23489,
#  24690,
#  25442,
#  26351,
#  27752,
#  29005,
#  30053,
#  30201,
#  30466,
#  30870,
#  32089,
#  32555,
#  33316,
#  36283,
#  38338,
#  38471,
#  38614,
#  39302,
#  39701,
#  39974,
#  40586,
#  40597,
#  40656,
#  41211,
#  41622,
#  41973,
#  42174,
#  42324,
#  42890,
#  44752,
#  45274,
#  45593,
#  46461,
#  47375,
#  47376,
#  48286,
#  49408,
#  49612,
#  50268,
#  51085,
#  52212,
#  52578,
#  53123,
#  53147,
#  53535,
#  54936,
#  55367,
#  55590,
#  55608,
#  55955,
#  56121,
#  56216,
#  56271,
#  56625,
#  57065,
#  57096,
#  57695,
#  59376,
#  59607,
#  60028,
#  60340,
#  60958,
#  61254,
#  61414,
#  62254,
#  62735,
#  63417,
#  63458,
#  64478,
#  65321,
#  65413,
#  66289,
#  67823,
#  68437,
#  70917,
#  70923,
#  73185,
#  73414,
#  73769,
#  75368,
#  75907,
#  76555,
#  76559,
#  76563,
#  76908,
#  77040,
#  77218,
#  77232,
#  77425,
#  77601,
#  78727,
#  78771,
#  79054,
#  80209,
#  80537,
#  81728,
#  82997,
#  84668,
#  85264,
#  88238,
#  88928,
#  89278,
#  91238,
#  91768,
#  92321,
#  92432,
#  99631,
#  99640,
#  104517,
#  105086,
#  106179,
#  106436,
#  106503,
#  106570,
#  106604,
#  107521,
#  107623,
#  107818,
#  108241,
#  108244,
#  108687,
#  111421,
#  112147,
#  112174,
#  112222,
#  112397,
#  112500,
#  113529,
#  114539,
#  115079,
#  118116,
#  118461,
#  118501,
#  119010,
#  120439,
#  120474,
#  120692,
#  120827,
#  120892,
#  121022,
#  122583,
#  122833,
#  123016,
#  124133,
#  124678,
#  124926,
#  125258,
#  125302,
#  125719,
#  125784,
#  125972,
#  126027,
#  126082,
#  126361,
#  127165,
#  130854,
#  131257,
#  132631,
#  132822,
#  133874,
#  133905,
#  135337,
#  137270,
#  138146,
#  140228,
#  140364,
#  141802,
#  142693,
#  142783,
#  144732,
#  145584,
#  147165,
#  147974,
#  149538,
#  149719,
#  150355,
#  151086,
#  152957,
#  153206,
#  153629,
#  153758,
#  154717,
#  154836]

# %% [markdown]
# Drop shifted rows and store in a new dataframe "drop_df_removed_shift"

# %%
drop_df_removed_shift = drop_df.drop(index= index_list_removed_shifted )
drop_df_removed_shift
# Out:
#                          Investors  \
# 0                        Techstars
# 1                     Y Combinator
# 2        Plug and Play Tech Center
# 3                         Gaingels
# 4                           Antler
# ...                            ...
# 155260          Ecosphere Ventures
# 155262       Ecostar (Accelerator)
# 155270  Ecosystem Ventures (India)
# 155314             Ecphora Capital
# 155331                 ECS Capital
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155260  Founded in 222, Ecosphere Ventures is a ventur...
# 155262  Founded in 216, Ecostar is an accelerator inve...
# 155270  Founded in 218, Ecosystem Ventures is an angel...
# 155314  Founded in 222, Ecphora Capital is a venture c...
# 155331  Founded in 26, ECS Capital is a private equity...
#
#                                                 Geography  \
# 0       Africa, Americas, Asia, Canada, Middle East, O...
# 1       Africa, Americas, Asia, Europe, Oceania, Unite...
# 2       Africa, Americas, Asia, Canada, Europe, Middle...
# 3       Africa, Americas, Asia, Canada, Europe, Middle...
# 4       Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                   ...
# 155260                                      United States
# 155262                                             Europe
# 155270                                               Asia
# 155314                                           Maryland
# 155331                                           Portugal
#
#                                        Preferred Industry  \
# 0       Beverages, Computer Hardware, Education and Tr...
# 1       Biotechnology, Commercial Transportation, Comm...
# 2       Aerospace and Defense, Animal Husbandry, Aquac...
# 3       Business Products and Services (B2B), Consumer...
# 4       Agriculture, Business Products and Services (B...
# ...                                                   ...
# 155260  Building Products, Commercial Transportation, ...
# 155262  Agriculture, Consumer Products and Services (B...
# 155270  Business Products and Services (B2B), Energy, ...
# 155314     Biotechnology, Healthcare Devices and Supplies
# 155331  Business Products and Services (B2B), Consumer...
#
#                                 Preferred Investment Type  \
# 0       Accelerator/Incubator, Early Stage VC, Later S...
# 1       Accelerator/Incubator, Early Stage VC, Later S...
# 2       Accelerator/Incubator, Early Stage VC, Later S...
# 3       Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4       Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                   ...
# 155260                         Early Stage VC, Seed Round
# 155262  Accelerator/Incubator, Debt Refinancing, Early...
# 155270         Early Stage VC, Later Stage VC, Seed Round
# 155314                         Early Stage VC, Seed Round
# 155331  Asset Acquisition, Buyout/LBO, Distressed Acqu...
#
#             Primary Investor Type  \
# 0           Accelerator/Incubator
# 1           Accelerator/Incubator
# 2           Accelerator/Incubator
# 3                 Venture Capital
# 4                 Venture Capital
# ...                           ...
# 155260   <span>0.00 - 1.00</span>
# 155262          <span>0.16</span>
# 155270   <span>0.25 - 1.00</span>
# 155314   <span>0.50 - 4.00</span>
# 155331  <span>5.17 - 51.74</span>
#
#                                            geography_tags  \
# 0       [africa, americas, asia, canada, middle east, ...
# 1       [africa, americas, asia, europe, oceania, unit...
# 2       [africa, americas, asia, canada, europe, middl...
# 3       [africa, americas, asia, canada, europe, middl...
# 4       [australia, brazil, canada, china, denmark, es...
# ...                                                   ...
# 155260                                    [united states]
# 155262                                           [europe]
# 155270                                             [asia]
# 155314                                         [maryland]
# 155331                                         [portugal]
#
#                            preferred_investment_type_tags  \
# 0       [accelerator/incubator, early stage vc, later ...
# 1       [accelerator/incubator, early stage vc, later ...
# 2       [accelerator/incubator, early stage vc, later ...
# 3       [early stage vc, later stage vc, pe growth/exp...
# 4       [accelerator/incubator, early stage vc, seed r...
# ...                                                   ...
# 155260                       [early stage vc, seed round]
# 155262  [accelerator/incubator, debt refinancing, earl...
# 155270       [early stage vc, later stage vc, seed round]
# 155314                       [early stage vc, seed round]
# 155331  [asset acquisition, buyout/lbo, distressed acq...
#
#                                   preferred_industry_tags
# 0       [beverages, computer hardware, education and t...
# 1       [biotechnology, commercial transportation, com...
# 2       [aerospace and defense, animal husbandry, aqua...
# 3       [business products and services (b2b), consume...
# 4       [agriculture, business products and services (...
# ...                                                   ...
# 155260  [building products, commercial transportation,...
# 155262  [agriculture, consumer products and services (...
# 155270  [business products and services (b2b), energy,...
# 155314   [biotechnology, healthcare devices and supplies]
# 155331  [business products and services (b2b), consume...
#
# [15219 rows x 9 columns]

# %% [markdown]
# **4. Work on One Hot Encoding**

# %%
geography_tags_list = drop_df_removed_shift['geography_tags'].explode().dropna().unique().tolist()
print("Geography Tags:", geography_tags_list)

df_to_excel = pd.DataFrame(geography_tags_list)
df_to_excel
# Out:
# Geography Tags: ['africa', 'americas', 'asia', 'canada', 'middle east', 'oceania', 'united kingdom', 'united states', 'europe', 'australia', 'brazil', 'china', 'denmark', 'estonia', 'france', 'germany', 'india', 'indonesia', 'japan', 'kenya', 'malaysia', 'netherlands', 'norway', 'pakistan', 'philippines', 'portugal', 'singapore', 'south korea', 'spain', 'sweden', 'thailand', 'united arab emirates', 'vietnam', 'north america', 'central america', 'south america', 'israel', 'ireland', 'bay area', 'mexico', 'new york', 'new york metro', 'costa rica', 'cuba', 'dominica', 'el salvador', 'east asia', 'mid atlantic', 'northeast', 'south asia', 'luxembourg', 'hong kong', 'southeast asia', 'taiwan', 'andorra', 'austria', 'belgium', 'czech republic', 'hungary', 'liechtenstein', 'monaco', 'northern europe', 'poland', 'slovakia', 'slovenia', 'switzerland', 'southern europe', 'western europe', 'midwest', 'southeast', 'west coast', 'eastern europe', 'south', 'new zealand', 'indiana', 'california', 'florida', 'saudi arabia', 'england', 'mountain', 'southern california', 'texas', 'north carolina', 'finland', 'iceland', 'italy', 'macau', 'mongolia', 'michigan', 'connecticut', 'argentina', 'bolivia', 'chile', 'colombia', 'ecuador', 'guatemala', 'honduras', 'nicaragua', 'panama', 'paraguay', 'peru', 'uruguay', 'venezuela', 'northwest', 'comoros', 'djibouti', 'mauritius', 'northern africa', 'somalia', 'kentucky', 'belize', 'dominican republic', 'guyana', 'haiti', 'suriname', 'massachusetts', 'scotland', 'caucasus', 'south africa', 'ethiopia', 'dc metro', 'delaware', 'district of columbia', 'great lakes', 'maryland', 'new england', 'new jersey', 'pennsylvania', 'southwest', 'us territories', 'virginia', 'west virginia', 'british columbia', 'quebec', 'turkey', 'central asia', 'eastern africa', 'western africa', 'north korea', 'greenland', 'egypt', 'romania', 'cook islands', 'fiji', 'french polynesia', 'kiribati', 'marshall islands', 'melanesia', 'micronesia', 'nauru', 'new caledonia', 'niue', 'northern mariana islands', 'palau', 'papua new guinea', 'pitcairn islands', 'samoa', 'solomon islands', 'tokelau', 'tonga', 'tuvalu', 'vanuatu', 'wallis and futuna', 'botswana', 'malawi', 'mozambique', 'namibia', 'rwanda', 'tanzania', 'uganda', 'zambia', 'zimbabwe', 'oklahoma', 'bangladesh', 'iowa', 'prince edward island', 'illinois', 'jordan', 'alaska', 'arizona', 'colorado', 'hawaii', 'idaho', 'montana', 'nevada', 'new mexico', 'oregon', 'utah', 'washington', 'wyoming', 'georgia', 'south carolina', 'tennessee', 'greece', 'wine brands intended to make acquisitions and roll up revenue.', 'sint maarten', 'founded in 2', 'ar audit &amp; research is a family office investment firm based in geneva', 'switzerland. the firm seeks to invest in different asset classes including hedge funds', 'private equity and venture funds', 'direct investments', 'real estate', 'collectibles', 'and liquid assets such as bonds', 'equities', 'and cash across the united states', 'asia europe', 'and africa. the firm prefers to invest in the fin-tech', 'health-tech', 'consumer', 'software', 'logistics', 'food-tech', 'clean-tech', 'ai', 'and robotics sectors.', 'board observer at console connect. he served as board member at defense.net. he co-founded &amp', 'middle africa', 'southern africa', 'faroe islands', 'serves as chief executive officer at finlight. mr. jean-bernard tanqueray served as partner at adan corporate. he was an mba candidate at london business school. he serves as the chief investment officer at single private family office. mr. tanqueray holds an mba from london business school', 'ukraine', 'kunkel. mr. curzon is a certified public accountant accredited in business valuation. he is a certified valuation analyst and a certified merger &amp', 'serves as managing director at lead dog ventures. mr. john landry is an angel investor. he also serves as board member at wespire.', '48', '65', 'wisconsin', 'chief executive officer at cpap.com.', 'founded in 215', 'ayady is a pri ...
#                                                      0
# 0                                               africa
# 1                                             americas
# 2                                                 asia
# 3                                               canada
# 4                                          middle east
# ..                                                 ...
# 573                                               chad
# 574  serves as chairman at hivello. he is a co-foun...
# 575  serves as chairman at red swan ventures. he is...
# 576                                      glass bottles
# 577                              mining and industrial
#
# [578 rows x 1 columns]

# %%
df_to_excel.columns = ['Location']
df_to_excel
# Out:
#                                               Location
# 0                                               africa
# 1                                             americas
# 2                                                 asia
# 3                                               canada
# 4                                          middle east
# ..                                                 ...
# 573                                               chad
# 574  serves as chairman at hivello. he is a co-foun...
# 575  serves as chairman at red swan ventures. he is...
# 576                                      glass bottles
# 577                              mining and industrial
#
# [578 rows x 1 columns]

# %%
# %pip install pycountry

import pandas as pd
import zipfile
import io
import requests
import pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 2.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.0/6.3 MB 2.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.3 MB 2.4 MB/s eta 0:00:02
#    ------------- -------------------------- 2.1/6.3 MB 2.5 MB/s eta 0:00:02
#    -------------- ------------------------- 2.4/6.3 MB 2.4 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.3 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 3.4/6.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 3.9/6.3 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: 下載並讀取 GeoNames 的城市資料
url = "http://download.geonames.org/export/dump/cities15000.zip"
response = requests.get(url)

if response.status_code == 200:
    with zipfile.ZipFile(io.BytesIO(response.content)) as z:
        with z.open('cities15000.txt') as f:
            columns = [
                'geonameid', 'name', 'asciiname', 'alternatenames', 'latitude', 'longitude',
                'feature_class', 'feature_code', 'country_code', 'cc2', 'admin1_code',
                'admin2_code', 'admin3_code', 'admin4_code', 'population', 'elevation',
                'dem', 'timezone', 'modification_date'
            ]
            df_geo = pd.read_csv(f, sep='\t', header=None, names=columns)
else:
    raise Exception("GeoNames 資料下載失敗，請檢查網路。")

# Step 2: 建立 地名 ➜ 國家名稱 的對照字典
def get_country_name(code):
    try:
        return pycountry.countries.get(alpha_2=code).name
    except:
        return None

df_geo['country_name'] = df_geo['country_code'].apply(get_country_name)

# 使用 asciiname 建立城市/地區 對應國家名
location_to_country = dict(zip(df_geo['asciiname'].str.lower(), df_geo['country_name']))

# 加上所有國家名稱的直接對應（像 "Germany" ➜ "Germany"）
for country in pycountry.countries:
    location_to_country[country.name.lower()] = country.name

# Step 3: 建立轉換函數
def standardize_location(value):
    if pd.isna(value):
        return 'N/A'
    name = value.strip().lower()
    return location_to_country.get(name, 'N/A')

# Step 4: 應用到你的 df_to_excel
df_to_excel['Standardized_Country'] = df_to_excel['Location'].apply(standardize_location)

# Step 5: 預覽結果（可省略）
print(df_to_excel[['Location', 'Standardized_Country']])

# Step 6: 儲存結果到 Excel
df_to_excel.to_excel('standardized_locations.xlsx', index=False)
# Out:
#                                               Location Standardized_Country
# 0                                               africa                  N/A
# 1                                             americas                  N/A
# 2                                                 asia          Philippines
# 3                                               canada               Canada
# 4                                          middle east                  N/A
# ..                                                 ...                  ...
# 573                                               chad                 Chad
# 574  serves as chairman at hivello. he is a co-foun...                  N/A
# 575  serves as chairman at red swan ventures. he is...                  N/A
# 576                                      glass bottles                  N/A
# 577                              mining and industrial                  N/A
#
# [578 rows x 2 columns]
