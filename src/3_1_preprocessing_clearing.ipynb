# %%
# !pip install nbformatv

# %%
# %run  2_get_data.ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement nbformatv (from versions: none)
# ERROR: No matching distribution found for nbformatv
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat in c:\programdata\anaconda3\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\programdata\anaconda3\lib\site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\programdata\anaconda3\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\programdata\anaconda3\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (305.1)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'

# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in c:\programdata\anaconda3\lib\site-packages (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\programdata\anaconda3\lib\site-packages (from pyarrow) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastparquet in c:\users\x\appdata\roaming\python\python312\site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (1.26.4)
# Requirement already satisfied: cramjam>=2.3 in c:\users\x\appdata\roaming\python\python312\site-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
# Define the path to your desktop
#desktop_path = os.path.expanduser("~/Desktop/")

# Define the file path for the CSV file on your desktop
#csv_file_path = os.path.join(desktop_path, 'output.csv')

# Export the DataFrame to a CSV file on your desktop
#combined_df.to_csv(csv_file_path, index=False)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330160 entries, 0 to 2330159
# Data columns (total 10 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Investors                       object
#  1   Primary Contact                 object
#  2   Description                     object
#  3   Geography                       object
#  4   Preferred Industry              object
#  5   Preferred Investment Type       object
#  6   Primary Investor Type           object
#  7   geography_tags                  object
#  8   preferred_investment_type_tags  object
#  9   preferred_industry_tags         object
# dtypes: object(10)
# memory usage: 177.8+ MB

# %%
combined_df.drop(columns=['Primary Contact'], inplace=True, errors='ignore')

# %%
print(combined_df)
# Out:
#                          Investors  \
# 0                        Techstars
# 1                     Y Combinator
# 2        Plug and Play Tech Center
# 3                         Gaingels
# 4                           Antler
# ...                            ...
# 2330155                 ECS Tuning
# 2330156                   ECSEL JU
# 2330157                     Ecster
# 2330158                 ECU Health
# 2330159              ECU Worldwide
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2330160 rows x 9 columns]

# %%
combined_df.isnull().sum()
# Out:
# Investors                            0
# Description                          0
# Geography                            0
# Preferred Industry                 210
# Preferred Investment Type         8700
# Primary Investor Type             9960
# geography_tags                       0
# preferred_investment_type_tags       0
# preferred_industry_tags              0
# dtype: int64

# %%
drop_df = combined_df.dropna()

# %%
print(drop_df)
# Out:
#                          Investors  \
# 0                        Techstars
# 1                     Y Combinator
# 2        Plug and Play Tech Center
# 3                         Gaingels
# 4                           Antler
# ...                            ...
# 2330155                 ECS Tuning
# 2330156                   ECSEL JU
# 2330157                     Ecster
# 2330158                 ECU Health
# 2330159              ECU Worldwide
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2320140 rows x 9 columns]

# %%
drop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2320140 entries, 0 to 2330159
# Data columns (total 9 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Investors                       object
#  1   Description                     object
#  2   Geography                       object
#  3   Preferred Industry              object
#  4   Preferred Investment Type       object
#  5   Primary Investor Type           object
#  6   geography_tags                  object
#  7   preferred_investment_type_tags  object
#  8   preferred_industry_tags         object
# dtypes: object(9)
# memory usage: 177.0+ MB

# %%
drop_df.columns
# Out:
# Index(['Investors', 'Description', 'Geography', 'Preferred Industry',
#        'Preferred Investment Type', 'Primary Investor Type', 'geography_tags',
#        'preferred_investment_type_tags', 'preferred_industry_tags'],
#       dtype='object')

# %%
drop_df = drop_df[~drop_df.isin(['', '0', '[]', '[0]']).any(axis=1)]

# %%
drop_df
# Out:
#                           Investors  \
# 0                         Techstars
# 1                      Y Combinator
# 2         Plug and Play Tech Center
# 3                          Gaingels
# 4                            Antler
# ...                             ...
# 2330076          Ecosphere Ventures
# 2330078       Ecostar (Accelerator)
# 2330086  Ecosystem Ventures (India)
# 2330130             Ecphora Capital
# 2330147                 ECS Capital
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330076  Founded in 222, Ecosphere Ventures is a ventur...
# 2330078  Founded in 216, Ecostar is an accelerator inve...
# 2330086  Founded in 218, Ecosystem Ventures is an angel...
# 2330130  Founded in 222, Ecphora Capital is a venture c...
# 2330147  Founded in 26, ECS Capital is a private equity...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330076                                      United States
# 2330078                                             Europe
# 2330086                                               Asia
# 2330130                                           Maryland
# 2330147                                           Portugal
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330076  Building Products, Commercial Transportation, ...
# 2330078  Agriculture, Consumer Products and Services (B...
# 2330086  Business Products and Services (B2B), Energy, ...
# 2330130     Biotechnology, Healthcare Devices and Supplies
# 2330147  Business Products and Services (B2B), Consumer...
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330076                         Early Stage VC, Seed Round
# 2330078  Accelerator/Incubator, Debt Refinancing, Early...
# 2330086         Early Stage VC, Later Stage VC, Seed Round
# 2330130                         Early Stage VC, Seed Round
# 2330147  Asset Acquisition, Buyout/LBO, Distressed Acqu...
#
#              Primary Investor Type  \
# 0            Accelerator/Incubator
# 1            Accelerator/Incubator
# 2            Accelerator/Incubator
# 3                  Venture Capital
# 4                  Venture Capital
# ...                            ...
# 2330076   <span>0.00 - 1.00</span>
# 2330078          <span>0.16</span>
# 2330086   <span>0.25 - 1.00</span>
# 2330130   <span>0.50 - 4.00</span>
# 2330147  <span>5.17 - 51.74</span>
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330076                                    [united states]
# 2330078                                           [europe]
# 2330086                                             [asia]
# 2330130                                         [maryland]
# 2330147                                         [portugal]
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330076                       [early stage vc, seed round]
# 2330078  [accelerator/incubator, debt refinancing, earl...
# 2330086       [early stage vc, later stage vc, seed round]
# 2330130                       [early stage vc, seed round]
# 2330147  [asset acquisition, buyout/lbo, distressed acq...
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330076  [building products, commercial transportation,...
# 2330078  [agriculture, consumer products and services (...
# 2330086  [business products and services (b2b), energy,...
# 2330130   [biotechnology, healthcare devices and supplies]
# 2330147  [business products and services (b2b), consume...
#
# [232890 rows x 9 columns]

# %%
drop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 232890 entries, 0 to 2330147
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Investors                       232890 non-null  object
#  1   Description                     232890 non-null  object
#  2   Geography                       232890 non-null  object
#  3   Preferred Industry              232890 non-null  object
#  4   Preferred Investment Type       232890 non-null  object
#  5   Primary Investor Type           232890 non-null  object
#  6   geography_tags                  232890 non-null  object
#  7   preferred_investment_type_tags  232890 non-null  object
#  8   preferred_industry_tags         232890 non-null  object
# dtypes: object(9)
# memory usage: 17.8+ MB

# %%
drop_df
# Out:
#                           Investors  \
# 0                         Techstars
# 1                      Y Combinator
# 2         Plug and Play Tech Center
# 3                          Gaingels
# 4                            Antler
# ...                             ...
# 2330076          Ecosphere Ventures
# 2330078       Ecostar (Accelerator)
# 2330086  Ecosystem Ventures (India)
# 2330130             Ecphora Capital
# 2330147                 ECS Capital
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330076  Founded in 222, Ecosphere Ventures is a ventur...
# 2330078  Founded in 216, Ecostar is an accelerator inve...
# 2330086  Founded in 218, Ecosystem Ventures is an angel...
# 2330130  Founded in 222, Ecphora Capital is a venture c...
# 2330147  Founded in 26, ECS Capital is a private equity...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330076                                      United States
# 2330078                                             Europe
# 2330086                                               Asia
# 2330130                                           Maryland
# 2330147                                           Portugal
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330076  Building Products, Commercial Transportation, ...
# 2330078  Agriculture, Consumer Products and Services (B...
# 2330086  Business Products and Services (B2B), Energy, ...
# 2330130     Biotechnology, Healthcare Devices and Supplies
# 2330147  Business Products and Services (B2B), Consumer...
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330076                         Early Stage VC, Seed Round
# 2330078  Accelerator/Incubator, Debt Refinancing, Early...
# 2330086         Early Stage VC, Later Stage VC, Seed Round
# 2330130                         Early Stage VC, Seed Round
# 2330147  Asset Acquisition, Buyout/LBO, Distressed Acqu...
#
#              Primary Investor Type  \
# 0            Accelerator/Incubator
# 1            Accelerator/Incubator
# 2            Accelerator/Incubator
# 3                  Venture Capital
# 4                  Venture Capital
# ...                            ...
# 2330076   <span>0.00 - 1.00</span>
# 2330078          <span>0.16</span>
# 2330086   <span>0.25 - 1.00</span>
# 2330130   <span>0.50 - 4.00</span>
# 2330147  <span>5.17 - 51.74</span>
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330076                                    [united states]
# 2330078                                           [europe]
# 2330086                                             [asia]
# 2330130                                         [maryland]
# 2330147                                         [portugal]
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330076                       [early stage vc, seed round]
# 2330078  [accelerator/incubator, debt refinancing, earl...
# 2330086       [early stage vc, later stage vc, seed round]
# 2330130                       [early stage vc, seed round]
# 2330147  [asset acquisition, buyout/lbo, distressed acq...
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330076  [building products, commercial transportation,...
# 2330078  [agriculture, consumer products and services (...
# 2330086  [business products and services (b2b), energy,...
# 2330130   [biotechnology, healthcare devices and supplies]
# 2330147  [business products and services (b2b), consume...
#
# [232890 rows x 9 columns]
