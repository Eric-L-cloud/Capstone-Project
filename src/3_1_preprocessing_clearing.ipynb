# %%
# %run  2_get_data.ipynb

# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
# Define the path to your desktop
#desktop_path = os.path.expanduser("~/Desktop/")

# Define the file path for the CSV file on your desktop
#csv_file_path = os.path.join(desktop_path, 'output.csv')

# Export the DataFrame to a CSV file on your desktop
#combined_df.to_csv(csv_file_path, index=False)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155344 entries, 0 to 155343
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Investors                       155344 non-null  object
#  1   Primary Contact                 155342 non-null  object
#  2   Description                     155344 non-null  object
#  3   Geography                       155344 non-null  object
#  4   Preferred Industry              155330 non-null  object
#  5   Preferred Investment Type       154764 non-null  object
#  6   Primary Investor Type           154680 non-null  object
#  7   geography_tags                  155344 non-null  object
#  8   preferred_investment_type_tags  155344 non-null  object
#  9   preferred_industry_tags         155344 non-null  object
# dtypes: object(10)
# memory usage: 11.9+ MB

# %%
combined_df = combined_df.drop(columns=['Primary Contact'])

# %%
#'Primary Contact' # useless unless the contact need analysis. 
#'Description' #useless unless the description need analysis. the description is not unique
combined_df = combined_df.drop_duplicates(subset=['Investors',   'Geography',
       'Preferred Industry', 'Preferred Investment Type',
       'Primary Investor Type'])

# %%
combined_df = combined_df[~combined_df['Description'].str.startswith('www.')]
combined_df
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# ...

# %%
combined_df = combined_df[~combined_df['Description'].str.contains('www.')]
combined_df
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# ...

# %%
combined_df.isin(['', '0', '[]', '[0]']).sum(axis=0)
# Out:
# Investors                              0
# Description                        10519
# Geography                         123693
# Preferred Industry                 63192
# Preferred Investment Type          31984
# Primary Investor Type              81883
# geography_tags                    123693
# preferred_investment_type_tags         0
# preferred_industry_tags                0
# dtype: int64

# %%
# need follow. if remove, many rows will be removed. May split into two parts.
combined_df[~combined_df.isin(['', '0', '[]', '[0]']).any(axis=1)]
# Out:
#                          Investors  \
# 0                        Techstars
# 1                     Y Combinator
# 2        Plug and Play Tech Center
# 3                         Gaingels
# 4                           Antler
# ...                            ...
# 155260          Ecosphere Ventures
# 155262       Ecostar (Accelerator)
# 155270  Ecosystem Ventures (India)
# 155314             Ecphora Capital
# 155331                 ECS Capital
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155260  Founded in 222, Ecosphere Ventures is a ventur...
# 155262  Founded in 216, Ecostar is an accelerator inve...
# ...

# %%
# accept, skip
combined_df[combined_df[['Description']].isin(['', '0', '[]', '[0]']).any(axis=1)]
# Out:
#                                 Investors Description  \
# 488     Amplify (Brand Experience Agency)
# 553                       Andorra Telecom
# 589                 Andrey Ostrovsky (US)
# 620                     Ironwood Insights
# 640                 IRSA Investments &amp
# ...                                   ...         ...
# 155330                         ECS Brands
# 155337                  ECS International
# 155338            ECS Investment Property
# 155340                           ECSEL JU
# 155342                         ECU Health
#
#                                                 Geography  \
# 488
# 553
# 589
# 620
# 640     IRSA Inversiones y Representaciones SA is enga...
# ...                                                   ...
# 155330
# 155337
# 155338
# 155340
# 155342
#
#                             Preferred Industry  \
# 488                                          0
# 553              Communications and Networking
# ...

# %%
combined_df=  combined_df.dropna()
combined_df
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# ...

# %%
#need follow, review
print(combined_df[combined_df.duplicated(subset=['Investors'])].shape)
combined_df[combined_df.duplicated(subset=['Investors'], keep=False)].sort_values(by='Investors')
# Out:
# (15502, 9)
#                    Investors  \
# 67954             Allen &amp
# 67953             Allen &amp
# 107520                B &amp
# 107519                B &amp
# 107548                 B&amp
# ...                      ...
# 27960   être Venture Capital
# 66354           İnci Holding
# 100533          İnci Holding
# 674                İş Enerji
# 101021             İş Enerji
#
#                                               Description  \
# 67954                                      allenovery.com
# 67953
# 107520                                  bcselfstorage.com
# 107519
# 107548
# ...                                                   ...
# 27960   Founded in 222, être Venture Capital is a vent...
# 66354   Manufacturer of battery production and sales i...
# 100533  Manufacturer of battery production and sales i...
# 674     Opearator of energy company intended to create...
# 101021  Opearator of energy company intended to create...
#
# ...

# %%
#need follow, tmp soluction
combined_df = combined_df.drop_duplicates(subset=['Investors'])

# %%
combined_df
# Out:
#                         Investors  \
# 0                       Techstars
# 1                    Y Combinator
# 2       Plug and Play Tech Center
# 3                        Gaingels
# 4                          Antler
# ...                           ...
# 155339                 ECS Tuning
# 155340                   ECSEL JU
# 155341                     Ecster
# 155342                 ECU Health
# 155343              ECU Worldwide
#
#                                               Description  \
# 0       Founded in 26, Techstars is an accelerator bas...
# 1       Founded in 25, Y Combinator is an accelerator ...
# 2       Founded in 26, Plug and Play Tech Center is an...
# 3       Founded in 214, Gaingels is a venture capital ...
# 4       Founded in 217, Antler is a venture capital in...
# ...                                                   ...
# 155339  Manufacturer and distributor of automotive par...
# 155340
# 155341  Operator of payment solutions for both busines...
# 155342
# ...

# %%
combined_df.columns
# Out:
# Index(['Investors', 'Description', 'Geography', 'Preferred Industry',
#        'Preferred Investment Type', 'Primary Investor Type', 'geography_tags',
#        'preferred_investment_type_tags', 'preferred_industry_tags'],
#       dtype='object')

# %%
df_clean = combined_df
