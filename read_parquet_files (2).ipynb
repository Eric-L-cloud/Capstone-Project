# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\leung\anaconda3\lib\site-packages (16.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.16.6 in c:\users\leung\anaconda3\lib\site-packages (from pyarrow) (1.26.4)

# %%
pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in c:\users\leung\anaconda3\lib\site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\leung\anaconda3\lib\site-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in c:\users\leung\anaconda3\lib\site-packages (from fastparquet) (1.26.4)
# Requirement already satisfied: cramjam>=2.3 in c:\users\leung\anaconda3\lib\site-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in c:\users\leung\anaconda3\lib\site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in c:\users\leung\appdata\roaming\python\python312\site-packages (from fastparquet) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leung\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leung\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leung\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\leung\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
num_files = 15
files = [f"files/batch_{i}.parquet" for i in range(num_files)]

dfs = [pd.read_parquet(files) for file in files]
combined_df = pd.concat(dfs, ignore_index=True)
combined_df
# Out:
#                          Investors                Primary Contact  \
# 0                        Techstars                    David Cohen
# 1                     Y Combinator                     David Lieb
# 2        Plug and Play Tech Center                   Marc Steiner
# 3                         Gaingels                Paul Grossinger
# 4                           Antler               Magnus Grimeland
# ...                            ...                            ...
# 2330155                 ECS Tuning                    Imran Jooma
# 2330156                   ECSEL JU                              0
# 2330157                     Ecster                              0
# 2330158                 ECU Health                Michael Waldrum
# 2330159              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2330160 rows x 10 columns]

# %%
import numpy as np
import os

# %%
# Define the path to your desktop
desktop_path = os.path.expanduser("~/Desktop/")

# Define the file path for the CSV file on your desktop
csv_file_path = os.path.join(desktop_path, 'output.csv')

# Export the DataFrame to a CSV file on your desktop
combined_df.to_csv(csv_file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 8
#       5 csv_file_path = os.path.join(desktop_path, 'output.csv')
#       7 # Export the DataFrame to a CSV file on your desktop
# ----> 8 combined_df.to_csv(csv_file_path, index=False)
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\leung\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:\Users\leung\Desktop'

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330160 entries, 0 to 2330159
# Data columns (total 10 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Investors                       object
#  1   Primary Contact                 object
#  2   Description                     object
#  3   Geography                       object
#  4   Preferred Industry              object
#  5   Preferred Investment Type       object
#  6   Primary Investor Type           object
#  7   geography_tags                  object
#  8   preferred_investment_type_tags  object
#  9   preferred_industry_tags         object
# dtypes: object(10)
# memory usage: 177.8+ MB

# %%
drop_df = combined_df.dropna()

# %%
print(drop_df)
# Out:
#                          Investors                Primary Contact  \
# 0                        Techstars                    David Cohen
# 1                     Y Combinator                     David Lieb
# 2        Plug and Play Tech Center                   Marc Steiner
# 3                         Gaingels                Paul Grossinger
# 4                           Antler               Magnus Grimeland
# ...                            ...                            ...
# 2330155                 ECS Tuning                    Imran Jooma
# 2330156                   ECSEL JU                              0
# 2330157                     Ecster                              0
# 2330158                 ECU Health                Michael Waldrum
# 2330159              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2320110 rows x 10 columns]

# %%
df_updated = drop_df.drop(['0', '[]', '[0]'], axis=1, errors = 'ignore')

# %%
print(df_updated)
# Out:
#                          Investors                Primary Contact  \
# 0                        Techstars                    David Cohen
# 1                     Y Combinator                     David Lieb
# 2        Plug and Play Tech Center                   Marc Steiner
# 3                         Gaingels                Paul Grossinger
# 4                           Antler               Magnus Grimeland
# ...                            ...                            ...
# 2330155                 ECS Tuning                    Imran Jooma
# 2330156                   ECSEL JU                              0
# 2330157                     Ecster                              0
# 2330158                 ECU Health                Michael Waldrum
# 2330159              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2320110 rows x 10 columns]

# %%
df_updated
# Out:
#                          Investors                Primary Contact  \
# 0                        Techstars                    David Cohen
# 1                     Y Combinator                     David Lieb
# 2        Plug and Play Tech Center                   Marc Steiner
# 3                         Gaingels                Paul Grossinger
# 4                           Antler               Magnus Grimeland
# ...                            ...                            ...
# 2330155                 ECS Tuning                    Imran Jooma
# 2330156                   ECSEL JU                              0
# 2330157                     Ecster                              0
# 2330158                 ECU Health                Michael Waldrum
# 2330159              ECU Worldwide  Shashi Kiran Janardhan Shetty
#
#                                                Description  \
# 0        Founded in 26, Techstars is an accelerator bas...
# 1        Founded in 25, Y Combinator is an accelerator ...
# 2        Founded in 26, Plug and Play Tech Center is an...
# 3        Founded in 214, Gaingels is a venture capital ...
# 4        Founded in 217, Antler is a venture capital in...
# ...                                                    ...
# 2330155  Manufacturer and distributor of automotive par...
# 2330156
# 2330157  Operator of payment solutions for both busines...
# 2330158
# 2330159  ECU Worldwide is a provider of logistic servic...
#
#                                                  Geography  \
# 0        Africa, Americas, Asia, Canada, Middle East, O...
# 1        Africa, Americas, Asia, Europe, Oceania, Unite...
# 2        Africa, Americas, Asia, Canada, Europe, Middle...
# 3        Africa, Americas, Asia, Canada, Europe, Middle...
# 4        Australia, Brazil, Canada, China, Denmark, Est...
# ...                                                    ...
# 2330155
# 2330156
# 2330157
# 2330158
# 2330159
#
#                                         Preferred Industry  \
# 0        Beverages, Computer Hardware, Education and Tr...
# 1        Biotechnology, Commercial Transportation, Comm...
# 2        Aerospace and Defense, Animal Husbandry, Aquac...
# 3        Business Products and Services (B2B), Consumer...
# 4        Agriculture, Business Products and Services (B...
# ...                                                    ...
# 2330155                Commercial Products, Transportation
# 2330156                           Semiconductors, Software
# 2330157                                                  0
# 2330158                                                  0
# 2330159                                          Logistics
#
#                                  Preferred Investment Type  \
# 0        Accelerator/Incubator, Early Stage VC, Later S...
# 1        Accelerator/Incubator, Early Stage VC, Later S...
# 2        Accelerator/Incubator, Early Stage VC, Later S...
# 3        Early Stage VC, Later Stage VC, PE Growth/Expa...
# 4        Accelerator/Incubator, Early Stage VC, Seed Round
# ...                                                    ...
# 2330155             Add-on, Buyout/LBO, Merger/Acquisition
# 2330156                                                  0
# 2330157                                 Merger/Acquisition
# 2330158                                 Merger/Acquisition
# 2330159                                 Merger/Acquisition
#
#          Primary Investor Type  \
# 0        Accelerator/Incubator
# 1        Accelerator/Incubator
# 2        Accelerator/Incubator
# 3              Venture Capital
# 4              Venture Capital
# ...                        ...
# 2330155                      0
# 2330156                      0
# 2330157                      0
# 2330158                      0
# 2330159                      0
#
#                                             geography_tags  \
# 0        [africa, americas, asia, canada, middle east, ...
# 1        [africa, americas, asia, europe, oceania, unit...
# 2        [africa, americas, asia, canada, europe, middl...
# 3        [africa, americas, asia, canada, europe, middl...
# 4        [australia, brazil, canada, china, denmark, es...
# ...                                                    ...
# 2330155                                                 []
# 2330156                                                 []
# 2330157                                                 []
# 2330158                                                 []
# 2330159                                                 []
#
#                             preferred_investment_type_tags  \
# 0        [accelerator/incubator, early stage vc, later ...
# 1        [accelerator/incubator, early stage vc, later ...
# 2        [accelerator/incubator, early stage vc, later ...
# 3        [early stage vc, later stage vc, pe growth/exp...
# 4        [accelerator/incubator, early stage vc, seed r...
# ...                                                    ...
# 2330155           [add-on, buyout/lbo, merger/acquisition]
# 2330156                                                [0]
# 2330157                               [merger/acquisition]
# 2330158                               [merger/acquisition]
# 2330159                               [merger/acquisition]
#
#                                    preferred_industry_tags
# 0        [beverages, computer hardware, education and t...
# 1        [biotechnology, commercial transportation, com...
# 2        [aerospace and defense, animal husbandry, aqua...
# 3        [business products and services (b2b), consume...
# 4        [agriculture, business products and services (...
# ...                                                    ...
# 2330155              [commercial products, transportation]
# 2330156                         [semiconductors, software]
# 2330157                                                [0]
# 2330158                                                [0]
# 2330159                                        [logistics]
#
# [2320110 rows x 10 columns]

# %%
df_updated['geography_tags']
# Out:
# 0          [africa, americas, asia, canada, middle east, ...
# 1          [africa, americas, asia, europe, oceania, unit...
# 2          [africa, americas, asia, canada, europe, middl...
# 3          [africa, americas, asia, canada, europe, middl...
# 4          [australia, brazil, canada, china, denmark, es...
#                                  ...
# 2330155                                                   []
# 2330156                                                   []
# 2330157                                                   []
# 2330158                                                   []
# 2330159                                                   []
# Name: geography_tags, Length: 2320110, dtype: object

# %%
split_df = pd.DataFrame(df_updated['preferred_investment_type_tags'].tolist())
split_df
# Out:
#                             0               1                    2   \
# 0        accelerator/incubator  early stage vc       later stage vc
# 1        accelerator/incubator  early stage vc       later stage vc
# 2        accelerator/incubator  early stage vc       later stage vc
# 3               early stage vc  later stage vc  pe growth/expansion
# 4        accelerator/incubator  early stage vc           seed round
# ...                        ...             ...                  ...
# 2320105                 add-on      buyout/lbo   merger/acquisition
# 2320106                      0            None                 None
# 2320107     merger/acquisition            None                 None
# 2320108     merger/acquisition            None                 None
# 2320109     merger/acquisition            None                 None
#
#                  3     4     5     6     7     8     9   ...    59    60  \
# 0        seed round  None  None  None  None  None  None  ...  None  None
# 1        seed round  None  None  None  None  None  None  ...  None  None
# 2        seed round  None  None  None  None  None  None  ...  None  None
# 3        seed round  None  None  None  None  None  None  ...  None  None
# 4              None  None  None  None  None  None  None  ...  None  None
# ...             ...   ...   ...   ...   ...   ...   ...  ...   ...   ...
# 2320105        None  None  None  None  None  None  None  ...  None  None
# 2320106        None  None  None  None  None  None  None  ...  None  None
# 2320107        None  None  None  None  None  None  None  ...  None  None
# 2320108        None  None  None  None  None  None  None  ...  None  None
# 2320109        None  None  None  None  None  None  None  ...  None  None
#
#            61    62    63    64    65    66    67    68
# 0        None  None  None  None  None  None  None  None
# 1        None  None  None  None  None  None  None  None
# 2        None  None  None  None  None  None  None  None
# 3        None  None  None  None  None  None  None  None
# 4        None  None  None  None  None  None  None  None
# ...       ...   ...   ...   ...   ...   ...   ...   ...
# 2320105  None  None  None  None  None  None  None  None
# 2320106  None  None  None  None  None  None  None  None
# 2320107  None  None  None  None  None  None  None  None
# 2320108  None  None  None  None  None  None  None  None
# 2320109  None  None  None  None  None  None  None  None
#
# [2320110 rows x 69 columns]
